# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc, precision_score, recall_score, f1_score, accuracy_score
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
import time

from google.colab import drive
drive.mount('/content/drive')

if torch.cuda.is_available():
  device = "cuda"
else:
  device = "cpu"

print(f'There are {torch.cuda.device_count()} GPU(s) available.')
print('Device name:', torch.cuda.get_device_name(0))

# Load dataset
df = pd.read_csv('/content/drive/MyDrive/CAN_Research/CANData/CAND/Silverado/attack-free-1.csv', delimiter=',')
df['arbitration_id'] = df['arbitration_id'].astype(str).dropna().apply(lambda x: float.fromhex(x))
df['data_field'] = df['data_field'].astype(str).dropna().apply(lambda x: float.fromhex(x))
df['attack'] = 0
df = df.loc[:50000, ['arbitration_id', 'data_field', 'attack']]

dg = pd.read_csv('/content/drive/MyDrive/CAN_Research/CANData/CAND/Silverado/DoS-1.csv', delimiter=',')
dg['arbitration_id'] = dg['arbitration_id'].astype(str).dropna().apply(lambda x: float.fromhex(x))
dg['data_field'] = dg['data_field'].astype(str).dropna().apply(lambda x: float.fromhex(x))
dg['attack'] = 1
dg = dg.loc[:50000, ['arbitration_id', 'data_field', 'attack']]

# Feature and label extraction
data = pd.concat([df, dg])
data = shuffle(data)

X = data[['arbitration_id', 'data_field']]
y = data['attack']

# Convert features to float
X = X.astype(float)

# Scaling the features
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# Reshape the features for LSTM
X_scaled = X_scaled.reshape(X_scaled.shape[0], 1, X_scaled.shape[1])

# Split the data into train, validation, and test sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=42)

# Convert to PyTorch tensors
X_train, y_train = torch.tensor(X_train, dtype=torch.float32), torch.tensor(y_train.values, dtype=torch.long)
X_val, y_val = torch.tensor(X_val, dtype=torch.float32), torch.tensor(y_val.values, dtype=torch.long)
X_test, y_test = torch.tensor(X_test, dtype=torch.float32), torch.tensor(y_test.values, dtype=torch.long)

# Create DataLoader
batch_size = 32

train_data = TensorDataset(X_train, y_train)
train_sampler = RandomSampler(train_data)
train_dataloader = DataLoader(train_data, sampler=train_sampler, batch_size=batch_size)

val_data = TensorDataset(X_val, y_val)
val_sampler = SequentialSampler(val_data)
val_dataloader = DataLoader(val_data, sampler=val_sampler, batch_size=batch_size)

test_data = TensorDataset(X_test, y_test)
test_sampler = SequentialSampler(test_data)
test_dataloader = DataLoader(test_data, sampler=test_sampler, batch_size=batch_size)

# Define LSTM model
class LSTMClassifier(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, n_layers, bidirectional, dropout):
        super(LSTMClassifier, self).__init__()
        self.lstm = nn.LSTM(input_dim, hidden_dim, num_layers=n_layers, bidirectional=bidirectional, dropout=(dropout if n_layers > 1 else 0), batch_first=True)
        self.fc = nn.Linear(hidden_dim * 2 if bidirectional else hidden_dim, output_dim)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        h0, c0 = self.init_hidden(x.size(0))
        out, _ = self.lstm(x, (h0, c0))
        out = self.fc(self.dropout(out[:, -1, :]))
        return out

    def init_hidden(self, batch_size):
        h0 = torch.zeros(self.lstm.num_layers * 2 if self.lstm.bidirectional else self.lstm.num_layers, batch_size, self.lstm.hidden_size).to(device)
        c0 = torch.zeros(self.lstm.num_layers * 2 if self.lstm.bidirectional else self.lstm.num_layers, batch_size, self.lstm.hidden_size).to(device)
        return h0, c0

# Hyperparameter tuning
hidden_dims = [128, 256]
n_layers_list = [1, 2]
bidirectional_list = [True, False]
dropout_rates = [0.2, 0.3]
learning_rates = [0.001, 0.0001]

best_model = None
best_score = 0
best_params = {}
best_training_time = 0

for hidden_dim in hidden_dims:
    for n_layers in n_layers_list:
        for bidirectional in bidirectional_list:
            for dropout in dropout_rates:
                for lr in learning_rates:
                    print(f"Training model with hidden_dim={hidden_dim}, n_layers={n_layers}, bidirectional={bidirectional}, dropout={dropout}, lr={lr}")
                    model = LSTMClassifier(input_dim=X_train.shape[2], hidden_dim=hidden_dim, output_dim=2, n_layers=n_layers, bidirectional=bidirectional, dropout=dropout)
                    model.to(device)

                    optimizer = optim.Adam(model.parameters(), lr=lr)
                    criterion = nn.CrossEntropyLoss()

                    patience = 2
                    early_stopping_counter = 0
                    best_validation_loss = float('inf')
                    loss_values, validation_loss_values = [], []

                    training_start_time = time.time()

                    for epoch_i in range(0, 10):  # Reduced epochs for faster tuning
                        print(f"Epoch {epoch_i + 1}/10")
                        model.train()
                        total_loss = 0

                        for step, batch in enumerate(train_dataloader):
                            b_input, b_labels = batch
                            b_input, b_labels = b_input.to(device), b_labels.to(device)

                            model.zero_grad()
                            outputs = model(b_input)
                            loss = criterion(outputs, b_labels)
                            total_loss += loss.item()

                            loss.backward()
                            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
                            optimizer.step()

                        avg_train_loss = total_loss / len(train_dataloader)
                        loss_values.append(avg_train_loss)
                        print(f'Average training loss: {avg_train_loss}')

                        print('Running Validation...')
                        model.eval()
                        eval_loss, eval_accuracy = 0, 0
                        nb_eval_steps, nb_eval_examples = 0, 0

                        for batch in val_dataloader:
                            b_input, b_labels = batch
                            b_input, b_labels = b_input.to(device), b_labels.to(device)

                            with torch.no_grad():
                                outputs = model(b_input)
                            loss = criterion(outputs, b_labels)
                            eval_loss += loss.item()
                            preds_flat = np.argmax(outputs.detach().cpu().numpy(), axis=1).flatten()
                            labels_flat = b_labels.cpu().numpy().flatten()
                            eval_accuracy += np.sum(preds_flat == labels_flat) / len(labels_flat)
                            nb_eval_steps += 1

                        avg_val_accuracy = eval_accuracy / nb_eval_steps
                        avg_val_loss = eval_loss / nb_eval_steps
                        validation_loss_values.append(avg_val_loss)
                        print(f'Validation Accuracy: {avg_val_accuracy}')
                        print(f'Validation Loss: {avg_val_loss}')

                        if avg_val_loss < best_validation_loss:
                            best_validation_loss = avg_val_loss
                            early_stopping_counter = 0
                            torch.save(model.state_dict(), 'best_lstm_model.pt')
                        else:
                            early_stopping_counter += 1

                        if early_stopping_counter >= patience:
                            print('Early stopping triggered.')
                            break

                    training_end_time = time.time()
                    training_time = training_end_time - training_start_time
                    print(f'Training time for this set of hyperparameters: {training_time:.2f} seconds')

                    if avg_val_accuracy > best_score:
                        best_score = avg_val_accuracy
                        best_model = model
                        best_params = {
                            'hidden_dim': hidden_dim,
                            'n_layers': n_layers,
                            'bidirectional': bidirectional,
                            'dropout': dropout,
                            'lr': lr
                        }
                        best_training_time = training_time

print(f"Best Model Parameters: {best_params}")
print(f"Best Validation Accuracy: {best_score:.4f}")
print(f"Best Training Time: {best_training_time:.2f} seconds")

# Load the best model
best_model.load_state_dict(torch.load('best_lstm_model.pt'))

# Evaluate on the test set
best_model.eval()
predictions, true_labels = [], []
test_start_time = time.time()

for batch in test_dataloader:
    b_input, b_labels = batch
    b_input, b_labels = b_input.to(device), b_labels.to(device)

    with torch.no_grad():
        outputs = best_model(b_input)

    logits = outputs.detach().cpu().numpy()
    label_ids = b_labels.to('cpu').numpy()
    predictions.extend(np.argmax(logits, axis=1).flatten())
    true_labels.extend(label_ids.flatten())

test_end_time = time.time()
test_time = test_end_time - test_start_time

print(f"Test complete! Total prediction time: {test_time:.2f} seconds")

# Classification report
print(classification_report(true_labels, predictions, digits=4))

# Confusion matrix
cm = confusion_matrix(true_labels, predictions)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# ROC curve
fpr, tpr, _ = roc_curve(true_labels, predictions)
roc_auc = auc(fpr, tpr)
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='grey', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# Bar plot for metrics
accuracy = accuracy_score(true_labels, predictions)
precision = precision_score(true_labels, predictions)
recall = recall_score(true_labels, predictions)
f1 = f1_score(true_labels, predictions)

metrics = {'Accuracy': accuracy, 'Precision': precision, 'Recall': recall, 'F1 Score': f1}
plt.figure(figsize=(8, 6))
plt.bar(metrics.keys(), metrics.values())
plt.ylim(0, 1)
plt.title('Metrics')
plt.show()

# Plot the learning curve
sns.set(style='darkgrid')
sns.set(font_scale=1.5)
plt.rcParams["figure.figsize"] = (12, 6)
plt.plot(loss_values, 'b-o', label="training loss")
plt.plot(validation_loss_values, 'r-o', label="validation loss")
plt.title("Learning curve")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.show()
# Out:
# Mounted at /content/drive
# There are 1 GPU(s) available.
# Device name: NVIDIA A100-SXM4-40GB
# Training model with hidden_dim=128, n_layers=1, bidirectional=True, dropout=0.2, lr=0.001
# Epoch 1/10
# Average training loss: 0.6933316749254862
# Running Validation...
# Validation Accuracy: 0.49715455271565495
# Validation Loss: 0.6942466983970362
# Epoch 2/10
# Average training loss: 0.6933037447611491
# Running Validation...
# Validation Accuracy: 0.5028953674121406
# Validation Loss: 0.6931659141287636
# Epoch 3/10
# Average training loss: 0.6932268562952677
# Running Validation...
# Validation Accuracy: 0.502845447284345
# Validation Loss: 0.6935966739448877
# Epoch 4/10
# Average training loss: 0.6932400778134664
# Running Validation...
# Validation Accuracy: 0.49715455271565495
# Validation Loss: 0.6936084713798742
# Early stopping triggered.
# Training time for this set of hyperparameters: 22.61 seconds
# Training model with hidden_dim=128, n_layers=1, bidirectional=True, dropout=0.2, lr=0.0001
# Epoch 1/10
# Average training loss: 0.6933736910184225
# Running Validation...
# Validation Accuracy: 0.502845447284345
# Validation Loss: 0.6931173381523583
# Epoch 2/10
# Average training loss: 0.6931667781194051
# Running Validation...
# Validation Accuracy: 0.4977535942492013
# Validation Loss: 0.6931834291345396
# Epoch 3/10
# Average training loss: 0.6931774822552998
# Running Validation...
# Validation Accuracy: 0.5029452875399361
# Validation Loss: 0.693152309320986
# Early stopping triggered.
# Training time for this set of hyperparameters: 16.37 seconds
# Training model with hidden_dim=128, n_layers=1, bidirectional=True, dropout=0.3, lr=0.001
# Epoch 1/10
# Average training loss: 0.6933827370643616
# Running Validation...
# Validation Accuracy: 0.49715455271565495
# Validation Loss: 0.6931679534455077
# Epoch 2/10
# Average training loss: 0.6933094649632772
# Running Validation...
# Validation Accuracy: 0.49715455271565495
# Validation Loss: 0.6936193042860245
# Epoch 3/10
# Average training loss: 0.6933471137682596
# Running Validation...
# Validation Accuracy: 0.4965555111821086
# Validation Loss: 0.6931790472409977
# Early stopping triggered.
# Training time for this set of hyperparameters: 16.32 seconds
# Training model with hidden_dim=128, n_layers=1, bidirectional=True, dropout=0.3, lr=0.0001
# Epoch 1/10
# Average training loss: 0.6933327253977458
# Running Validation...
# Validation Accuracy: 0.502845447284345
# Validation Loss: 0.6931390908008186
# Epoch 2/10
# Average training loss: 0.6931892915089926
# Running Validation...
# Validation Accuracy: 0.4965555111821086
# Validation Loss: 0.693159004655509
# Epoch 3/10
# Average training loss: 0.6932018646558126
# Running Validation...
# Validation Accuracy: 0.4956070287539936
# Validation Loss: 0.6931712153239753
# Early stopping triggered.
# Training time for this set of hyperparameters: 16.21 seconds
# Training model with hidden_dim=128, n_layers=1, bidirectional=False, dropout=0.2, lr=0.001
# Epoch 1/10
# Average training loss: 0.6933525186538696
# Running Validation...
# Validation Accuracy: 0.4968051118210863
# Validation Loss: 0.6931658876589692
# Epoch 2/10
# Average training loss: 0.6932297758102417
# Running Validation...
# Validation Accuracy: 0.502845447284345
# Validation Loss: 0.6931679869612185
# Epoch 3/10
# Average training loss: 0.6931713044802348
# Running Validation...
# Validation Accuracy: 0.49715455271565495
# Validation Loss: 0.6932860199635783
# Early stopping triggered.
# Training time for this set of hyperparameters: 15.04 seconds
# Training model with hidden_dim=128, n_layers=1, bidirectional=False, dropout=0.2, lr=0.0001
# Epoch 1/10
# Average training loss: 0.6932174644470215
# Running Validation...
# Validation Accuracy: 0.502845447284345
# Validation Loss: 0.6931466307883827
# Epoch 2/10
# Average training loss: 0.6931876576741537
# Running Validation...
# Validation Accuracy: 0.5020467252396166
# Validation Loss: 0.6931557364928456
# Epoch 3/10
# Average training loss: 0.6931729827562968
# Running Validation...
# Validation Accuracy: 0.4985023961661342
# Validation Loss: 0.6931920074426328
# Early stopping triggered.
# Training time for this set of hyperparameters: 15.11 seconds
# Training model with hidden_dim=128, n_layers=1, bidirectional=False, dropout=0.3, lr=0.001
# Epoch 1/10
# Average training loss: 0.693366315205892
# Running Validation...
# Validation Accuracy: 0.502845447284345
# Validation Loss: 0.6931696720778371
# Epoch 2/10
# Average training loss: 0.6932273132006327
# Running Validation...
# Validation Accuracy: 0.502845447284345
# Validation Loss: 0.6931519103697694
# Epoch 3/10
# Average training loss: 0.6932598148028056
# Running Validation...
# Validation Accuracy: 0.502845447284345
# Validation Loss: 0.693134737567018
# Epoch 4/10
# Average training loss: 0.6932450891494751
# Running Validation...
# Validation Accuracy: 0.49820287539936103
# Validation Loss: 0.6931555202593819
# Epoch 5/10
# Average training loss: 0.6932464694976807
# Running Validation...
# Validation Accuracy: 0.502845447284345
# Validation Loss: 0.693183568910288
# Early stopping triggered.
# Training time for this set of hyperparameters: 25.31 seconds
# Training model with hidden_dim=128, n_layers=1, bidirectional=False, dropout=0.3, lr=0.0001
# Epoch 1/10
# Average training loss: 0.6931950894673665
# Running Validation...
# Validation Accuracy: 0.502845447284345
# Validation Loss: 0.6931367216590113
# Epoch 2/10
# Average training loss: 0.6931954424858093
# Running Validation...
# Validation Accuracy: 0.49715455271565495
# Validation Loss: 0.6931781616454689
# Epoch 3/10
# Average training loss: 0.6931928414026897
# Running Validation...
# Validation Accuracy: 0.5019968051118211
# Validation Loss: 0.6931517363165896
# Early stopping triggered.
# Training time for this set of hyperparameters: 14.98 seconds
# Training model with hidden_dim=128, n_layers=2, bidirectional=True, dropout=0.2, lr=0.001
# Epoch 1/10
# Average training loss: 0.6933968793551127
# Running Validation...
# Validation Accuracy: 0.5023961661341853
# Validation Loss: 0.6931462157458163
# Epoch 2/10
# Average training loss: 0.693249872970581
# Running Validation...
# Validation Accuracy: 0.49715455271565495
# Validation Loss: 0.693161607645571
# Epoch 3/10
# Average training loss: 0.6932454487482707
# Running Validation...
# Validation Accuracy: 0.49715455271565495
# Validation Loss: 0.6932713608391369
# Early stopping triggered.
# Training time for this set of hyperparameters: 19.56 seconds
# Training model with hidden_dim=128, n_layers=2, bidirectional=True, dropout=0.2, lr=0.0001
# Epoch 1/10
# Average training loss: 0.693212402121226
# Running Validation...
# Validation Accuracy: 0.49715455271565495
# Validation Loss: 0.6932143563279709
# Epoch 2/10
# Average training loss: 0.6931896679878234
# Running Validation...
# Validation Accuracy: 0.49715455271565495
# Validation Loss: 0.693371068460111
# Epoch 3/10
# Average training loss: 0.6932146007537842
# Running Validation...
# Validation Accuracy: 0.502845447284345
# Validation Loss: 0.6931511712150452
# Epoch 4/10
# Average training loss: 0.693201679611206
# Running Validation...
# Validation Accuracy: 0.49715455271565495
# Validation Loss: 0.6932068552833777
# Epoch 5/10
# Average training loss: 0.6931884749094646
# Running Validation...
# Validation Accuracy: 0.502845447284345
# Validation Loss: 0.6931543491138056
# Early stopping triggered.
# Training time for this set of hyperparameters: 32.41 seconds
# Training model with hidden_dim=128, n_layers=2, bidirectional=True, dropout=0.3, lr=0.001
# Epoch 1/10
# Average training loss: 0.6934224407513936
# Running Validation...
# Validation Accuracy: 0.502845447284345
# Validation Loss: 0.6931478809624815
# Epoch 2/10
# Average training loss: 0.6932993314425151
# Running Validation...
# Validation Accuracy: 0.5023961661341853
# Validation Loss: 0.6931465203388811
# Epoch 3/10
# Average training loss: 0.693252997303009
# Running Validation...
# Validation Accuracy: 0.49715455271565495
# Validation Loss: 0.6931562800757801
# Epoch 4/10
# Average training loss: 0.6932593947092692
# Running Validation...
# Validation Accuracy: 0.49715455271565495
# Validation Loss: 0.6932299329449956
# Early stopping triggered.
# Training time for this set of hyperparameters: 26.09 seconds
# Training model with hidden_dim=128, n_layers=2, bidirectional=True, dropout=0.3, lr=0.0001
# Epoch 1/10
# Average training loss: 0.6932905286471049
# Running Validation...
# Validation Accuracy: 0.502845447284345
# Validation Loss: 0.6931448839723874
# Epoch 2/10
# Average training loss: 0.6931862273852031
# Running Validation...
# Validation Accuracy: 0.49715455271565495
# Validation Loss: 0.6931963727687495
# Epoch 3/10
# Average training loss: 0.6931929216066997
# Running Validation...
# Validation Accuracy: 0.502845447284345
# Validation Loss: 0.6931569141130478
# Early stopping triggered.
# Training time for this set of hyperparameters: 19.47 seconds
# Training model with hidden_dim=128, n_layers=2, bidirectional=False, dropout=0.2, lr=0.001
# Epoch 1/10
# Average training loss: 0.693336346912384
# Running Validation...
# Validation Accuracy: 0.49715455271565495
# Validation Loss: 0.6933672410040237
# Epoch 2/10
# Average training loss: 0.6932494428952535
# Running Validation...
# Validation Accuracy: 0.49715455271565495
# Validation Loss: 0.6932597863978852
# Epoch 3/10
# Average training loss: 0.6932530446052552
# Running Validation...
# Validation Accuracy: 0.49715455271565495
# Validation Loss: 0.6931890279721147
# Epoch 4/10
# Average training loss: 0.6932457571029663
# Running Validation...
# Validation Accuracy: 0.502845447284345
# Validation Loss: 0.6931639050904174
# Epoch 5/10
# Average training loss: 0.6932276882807413
# Running Validation...
# Validation Accuracy: 0.502845447284345
# Validation Loss: 0.6931391766848275
# Epoch 6/10
# Average training loss: 0.6932341925303142
# Running Validation...
# Validation Accuracy: 0.502845447284345
# Validation Loss: 0.6931376381042286
# Epoch 7/10
# Average training loss: 0.693214088789622
# Running Validation...
# Validation Accuracy: 0.502845447284345
# Validation Loss: 0.6931359457512634
# Epoch 8/10
# Average training loss: 0.6932368915875753
# Running Validation...
# Validation Accuracy: 0.49715455271565495
# Validation Loss: 0.6931696433228807
# Epoch 9/10
# Average training loss: 0.6932188514073689
# Running Validation...
# Validation Accuracy: 0.4983526357827476
# Validation Loss: 0.6931449539554767
# Early stopping triggered.
# Training time for this set of hyperparameters: 49.33 seconds
# Training model with hidden_dim=128, n_layers=2, bidirectional=False, dropout=0.2, lr=0.0001
# Epoch 1/10
# Average training loss: 0.6931789019584655
# Running Validation...
# Validation Accuracy: 0.502845447284345
# Validation Loss: 0.6931458015601856
# Epoch 2/10
# Average training loss: 0.6931824626922607
# Running Validation...
# Validation Accuracy: 0.49675519169329074
# Validation Loss: 0.693152410439409
# Epoch 3/10
# Average training loss: 0.6931801559130351
# Running Validation...
# Validation Accuracy: 0.502845447284345
# Validation Loss: 0.6931473522331006
# Early stopping triggered.
# Training time for this set of hyperparameters: 16.44 seconds
# Training model with hidden_dim=128, n_layers=2, bidirectional=False, dropout=0.3, lr=0.001
# Epoch 1/10
# Average training loss: 0.6932665686925252
# Running Validation...
# Validation Accuracy: 0.49715455271565495
# Validation Loss: 0.6957238458406431
# Epoch 2/10
# Average training loss: 0.6933207514762878
# Running Validation...
# Validation Accuracy: 0.502845447284345
# Validation Loss: 0.6931425790055491
# Epoch 3/10
# Average training loss: 0.6932110321680705
# Running Validation...
# Validation Accuracy: 0.502845447284345
# Validation Loss: 0.693141579913636
# Epoch 4/10
# Average training loss: 0.6932377345403036
# Running Validation...
# Validation Accuracy: 0.49715455271565495
# Validation Loss: 0.6932531525723089
# Epoch 5/10
# Average training loss: 0.6931866912523905
# Running Validation...
# Validation Accuracy: 0.502845447284345
# Validation Loss: 0.6932288047414237
# Early stopping triggered.
# Training time for this set of hyperparameters: 27.46 seconds
# Training model with hidden_dim=128, n_layers=2, bidirectional=False, dropout=0.3, lr=0.0001
# Epoch 1/10
# Average training loss: 0.6931930921554565
# Running Validation...
# Validation Accuracy: 0.49715455271565495
# Validation Loss: 0.6931644169667277
# Epoch 2/10
# Average training loss: 0.6932293449401855
# Running Validation...
# Validation Accuracy: 0.49715455271565495
# Validation Loss: 0.6931725271022358
# Epoch 3/10
# Average training loss: 0.6931815212885539
# Running Validation...
# Validation Accuracy: 0.49715455271565495
# Validation Loss: 0.693204475858341
# Early stopping triggered.
# Training time for this set of hyperparameters: 16.39 seconds
# Training model with hidden_dim=256, n_layers=1, bidirectional=True, dropout=0.2, lr=0.001
# Epoch 1/10
# Average training loss: 0.6933925457000732
# Running Validation...
# Validation Accuracy: 0.502845447284345
# Validation Loss: 0.6933281346441458
# Epoch 2/10
# Average training loss: 0.6932771679242452
# Running Validation...
# Validation Accuracy: 0.5021964856230032
# Validation Loss: 0.6932359664394452
# Epoch 3/10
# Average training loss: 0.6933024080912272
# Running Validation...
# Validation Accuracy: 0.49715455271565495
# Validation Loss: 0.6934395919973477
# Epoch 4/10
# Average training loss: 0.6932871774673461
# Running Validation...
# Validation Accuracy: 0.501797124600639
# Validation Loss: 0.6931811138844719
# Epoch 5/10
# Average training loss: 0.6932561336199442
# Running Validation...
# Validation Accuracy: 0.49715455271565495
# Validation Loss: 0.6936592468248007
# Epoch 6/10
# Average training loss: 0.6932635944684347
# Running Validation...
# Validation Accuracy: 0.49715455271565495
# Validation Loss: 0.6932263693299157
# Early stopping triggered.
# Training time for this set of hyperparameters: 34.56 seconds
# Training model with hidden_dim=256, n_layers=1, bidirectional=True, dropout=0.2, lr=0.0001
# Epoch 1/10
# Average training loss: 0.6931942509015401
# Running Validation...
# Validation Accuracy: 0.49715455271565495
# Validation Loss: 0.6932382489355228
# Epoch 2/10
# Average training loss: 0.6932080947875977
# Running Validation...
# Validation Accuracy: 0.4960063897763578
# Validation Loss: 0.6931685084542527
# Epoch 3/10
# Average training loss: 0.6931987532933553
# Running Validation...
# Validation Accuracy: 0.5020966453674122
# Validation Loss: 0.693171044222463
# Epoch 4/10
# Average training loss: 0.6931675045331319
# Running Validation...
# Validation Accuracy: 0.4967052715654952
# Validation Loss: 0.6931782308668374
# Early stopping triggered.
# Training time for this set of hyperparameters: 23.05 seconds
# Training model with hidden_dim=256, n_layers=1, bidirectional=True, dropout=0.3, lr=0.001
# Epoch 1/10
# Average training loss: 0.6933211569150289
# Running Validation...
# Validation Accuracy: 0.502845447284345
# Validation Loss: 0.6938656027705524
# Epoch 2/10
# Average training loss: 0.6933721232096354
# Running Validation...
# Validation Accuracy: 0.49715455271565495
# Validation Loss: 0.6934195628371863
# Epoch 3/10
# Average training loss: 0.693314774386088
# Running Validation...
# Validation Accuracy: 0.4968051118210863
# Validation Loss: 0.6934113264464723
# Epoch 4/10
# Average training loss: 0.6933048638343811
# Running Validation...
# Validation Accuracy: 0.49715455271565495
# Validation Loss: 0.6935332044244955
# Epoch 5/10
# Average training loss: 0.6933622141838074
# Running Validation...
# Validation Accuracy: 0.49715455271565495
# Validation Loss: 0.6933144181490706
# Epoch 6/10
# Average training loss: 0.693308092435201
# Running Validation...
# Validation Accuracy: 0.502845447284345
# Validation Loss: 0.6932445591250167
# Epoch 7/10
# Average training loss: 0.6932351934750874
# Running Validation...
# Validation Accuracy: 0.4966553514376997
# Validation Loss: 0.6931628836229586
# Epoch 8/10
# Average training loss: 0.6932770188649495
# Running Validation...
# Validation Accuracy: 0.4966553514376997
# Validation Loss: 0.6932298179251698
# Epoch 9/10
# Average training loss: 0.6932925820032756
# Running Validation...
# Validation Accuracy: 0.4965055910543131
# Validation Loss: 0.6931850811163076
# Early stopping triggered.
# Training time for this set of hyperparameters: 51.95 seconds
# Training model with hidden_dim=256, n_layers=1, bidirectional=True, dropout=0.3, lr=0.0001
# Epoch 1/10
# Average training loss: 0.6932051853179931
# Running Validation...
# Validation Accuracy: 0.5020966453674122
# Validation Loss: 0.6931518107747879
# Epoch 2/10
# Average training loss: 0.6932093460718791
# Running Validation...
# Validation Accuracy: 0.5023961661341853
# Validation Loss: 0.6931580633591539
# Epoch 3/10
# Average training loss: 0.6932024958928427
# Running Validation...
# Validation Accuracy: 0.5020966453674122
# Validation Loss: 0.6931593798981688
# Early stopping triggered.
# Training time for this set of hyperparameters: 17.26 seconds
# Training model with hidden_dim=256, n_layers=1, bidirectional=False, dropout=0.2, lr=0.001
# Epoch 1/10
# Average training loss: 0.693358531665802
# Running Validation...
# Validation Accuracy: 0.5030451277955271
# Validation Loss: 0.6931434845962463
# Epoch 2/10
# Average training loss: 0.6932181538263956
# Running Validation...
# Validation Accuracy: 0.502845447284345
# Validation Loss: 0.6931551001704158
# Epoch 3/10
# Average training loss: 0.6932157270431518
# Running Validation...
# Validation Accuracy: 0.49715455271565495
# Validation Loss: 0.6940923031336202
# Early stopping triggered.
# Training time for this set of hyperparameters: 15.55 seconds
# Training model with hidden_dim=256, n_layers=1, bidirectional=False, dropout=0.2, lr=0.0001
# Epoch 1/10
# Average training loss: 0.6932119384447734
# Running Validation...
# Validation Accuracy: 0.4968051118210863
# Validation Loss: 0.6931836708856467
# Epoch 2/10
# Average training loss: 0.6931875257809957
# Running Validation...
# Validation Accuracy: 0.4971046325878594
# Validation Loss: 0.6931769785027915
# Epoch 3/10
# Average training loss: 0.6931671405474344
# Running Validation...
# Validation Accuracy: 0.501797124600639
# Validation Loss: 0.6931504023532136
# Epoch 4/10
# Average training loss: 0.6931701853434244
# Running Validation...
# Validation Accuracy: 0.502845447284345
# Validation Loss: 0.6931672272400353
# Epoch 5/10
# Average training loss: 0.6931903548240662
# Running Validation...
# Validation Accuracy: 0.501797124600639
# Validation Loss: 0.6931591191992592
# Early stopping triggered.
# Training time for this set of hyperparameters: 25.91 seconds
# Training model with hidden_dim=256, n_layers=1, bidirectional=False, dropout=0.3, lr=0.001
# Epoch 1/10
# Average training loss: 0.6933609975179037
# Running Validation...
# Validation Accuracy: 0.502845447284345
# Validation Loss: 0.6931349026699798
# Epoch 2/10
# Average training loss: 0.6932862284342448
# Running Validation...
# Validation Accuracy: 0.49645567092651754
# Validation Loss: 0.6932169338003896
# Epoch 3/10
# Average training loss: 0.6932442668914794
# Running Validation...
# Validation Accuracy: 0.49715455271565495
# Validation Loss: 0.6935285534531164
# Early stopping triggered.
# Training time for this set of hyperparameters: 15.54 seconds
# Training model with hidden_dim=256, n_layers=1, bidirectional=False, dropout=0.3, lr=0.0001
# Epoch 1/10
# Average training loss: 0.6931710032463074
# Running Validation...
# Validation Accuracy: 0.49715455271565495
# Validation Loss: 0.6931650695709375
# Epoch 2/10
# Average training loss: 0.6932120226224263
# Running Validation...
# Validation Accuracy: 0.502845447284345
# Validation Loss: 0.6931472660634465
# Epoch 3/10
# Average training loss: 0.6931923589388529
# Running Validation...
# Validation Accuracy: 0.5020966453674122
# Validation Loss: 0.6931545628716771
# Epoch 4/10
# Average training loss: 0.6931738187472025
# Running Validation...
# Validation Accuracy: 0.49715455271565495
# Validation Loss: 0.6932055012296183
# Early stopping triggered.
# Training time for this set of hyperparameters: 20.71 seconds
# Training model with hidden_dim=256, n_layers=2, bidirectional=True, dropout=0.2, lr=0.001
# Epoch 1/10
# Average training loss: 0.6933493321100871
# Running Validation...
# Validation Accuracy: 0.49715455271565495
# Validation Loss: 0.6933447558658953
# Epoch 2/10
# Average training loss: 0.6932878331184387
# Running Validation...
# Validation Accuracy: 0.502845447284345
# Validation Loss: 0.6931399608762882
# Epoch 3/10
# Average training loss: 0.6932462932904562
# Running Validation...
# Validation Accuracy: 0.502845447284345
# Validation Loss: 0.693153231955184
# Epoch 4/10
# Average training loss: 0.6932927424112956
# Running Validation...
# Validation Accuracy: 0.49715455271565495
# Validation Loss: 0.6931837753365977
# Early stopping triggered.
# Training time for this set of hyperparameters: 27.56 seconds
# Training model with hidden_dim=256, n_layers=2, bidirectional=True, dropout=0.2, lr=0.0001
# Epoch 1/10
# Average training loss: 0.6932497327486674
# Running Validation...
# Validation Accuracy: 0.49570686900958466
# Validation Loss: 0.6931643842127376
# Epoch 2/10
# Average training loss: 0.6932280273119609
# Running Validation...
# Validation Accuracy: 0.5020966453674122
# Validation Loss: 0.693152734646782
# Epoch 3/10
# Average training loss: 0.6932205317497253
# Running Validation...
# Validation Accuracy: 0.49640575079872207
# Validation Loss: 0.693172811319272
# Epoch 4/10
# Average training loss: 0.6931848464330037
# Running Validation...
# Validation Accuracy: 0.5020966453674122
# Validation Loss: 0.6931597026773154
# Early stopping triggered.
# Training time for this set of hyperparameters: 27.66 seconds
# Training model with hidden_dim=256, n_layers=2, bidirectional=True, dropout=0.3, lr=0.001
# Epoch 1/10
# Average training loss: 0.6934611359914143
# Running Validation...
# Validation Accuracy: 0.49715455271565495
# Validation Loss: 0.6933119394146977
# Epoch 2/10
# Average training loss: 0.6932968734105428
# Running Validation...
# Validation Accuracy: 0.502845447284345
# Validation Loss: 0.6931309919006908
# Epoch 3/10
# Average training loss: 0.6933113552093506
# Running Validation...
# Validation Accuracy: 0.502845447284345
# Validation Loss: 0.6932291798888685
# Epoch 4/10
# Average training loss: 0.6933150903066
# Running Validation...
# Validation Accuracy: 0.502845447284345
# Validation Loss: 0.6931817055510255
# Early stopping triggered.
# Training time for this set of hyperparameters: 27.73 seconds
# Training model with hidden_dim=256, n_layers=2, bidirectional=True, dropout=0.3, lr=0.0001
# Epoch 1/10
# Average training loss: 0.6932221487363179
# Running Validation...
# Validation Accuracy: 0.502845447284345
# Validation Loss: 0.6931826165689828
# Epoch 2/10
# Average training loss: 0.6932128190676371
# Running Validation...
# Validation Accuracy: 0.502845447284345
# Validation Loss: 0.6931532295748067
# Epoch 3/10
# Average training loss: 0.6932218824704488
# Running Validation...
# Validation Accuracy: 0.49715455271565495
# Validation Loss: 0.6931733348118231
# Epoch 4/10
# Average training loss: 0.6931757778485617
# Running Validation...
# Validation Accuracy: 0.502845447284345
# Validation Loss: 0.6931993112967799
# Early stopping triggered.
# Training time for this set of hyperparameters: 27.50 seconds
# Training model with hidden_dim=256, n_layers=2, bidirectional=False, dropout=0.2, lr=0.001
# Epoch 1/10
# Average training loss: 0.6933376616795858
# Running Validation...
# Validation Accuracy: 0.49715455271565495
# Validation Loss: 0.6939770692644028
# Epoch 2/10
# Average training loss: 0.6933003964424134
# Running Validation...
# Validation Accuracy: 0.502845447284345
# Validation Loss: 0.6931372802859297
# Epoch 3/10
# Average training loss: 0.6931856739997864
# Running Validation...
# Validation Accuracy: 0.49715455271565495
# Validation Loss: 0.6933311555332269
# Epoch 4/10
# Average training loss: 0.6932620383262634
# Running Validation...
# Validation Accuracy: 0.502845447284345
# Validation Loss: 0.6931370980442523
# Epoch 5/10
# Average training loss: 0.6932233968734741
# Running Validation...
# Validation Accuracy: 0.502845447284345
# Validation Loss: 0.693221594864568
# Epoch 6/10
# Average training loss: 0.6932360197703044
# Running Validation...
# Validation Accuracy: 0.502845447284345
# Validation Loss: 0.6935574928411661
# Early stopping triggered.
# Training time for this set of hyperparameters: 34.78 seconds
# Training model with hidden_dim=256, n_layers=2, bidirectional=False, dropout=0.2, lr=0.0001
# Epoch 1/10
# Average training loss: 0.6931819856325785
# Running Validation...
# Validation Accuracy: 0.502845447284345
# Validation Loss: 0.6931471742761021
# Epoch 2/10
# Average training loss: 0.6931811619122823
# Running Validation...
# Validation Accuracy: 0.502845447284345
# Validation Loss: 0.6932561547040178
# Epoch 3/10
# Average training loss: 0.6932395933787028
# Running Validation...
# Validation Accuracy: 0.501797124600639
# Validation Loss: 0.6931442734532463
# Epoch 4/10
# Average training loss: 0.6931780902862549
# Running Validation...
# Validation Accuracy: 0.49715455271565495
# Validation Loss: 0.6932157140951187
# Epoch 5/10
# Average training loss: 0.693155891418457
# Running Validation...
# Validation Accuracy: 0.49715455271565495
# Validation Loss: 0.6932306370605676
# Early stopping triggered.
# Training time for this set of hyperparameters: 28.91 seconds
# Training model with hidden_dim=256, n_layers=2, bidirectional=False, dropout=0.3, lr=0.001
# Epoch 1/10
# Average training loss: 0.6933391482353211
# Running Validation...
# Validation Accuracy: 0.502845447284345
# Validation Loss: 0.693137164123523
# Epoch 2/10
# Average training loss: 0.6933179810523987
# Running Validation...
# Validation Accuracy: 0.5028953674121406
# Validation Loss: 0.6931352869580729
# Epoch 3/10
# Average training loss: 0.6933043243726095
# Running Validation...
# Validation Accuracy: 0.5033945686900958
# Validation Loss: 0.6931250899934921
# Epoch 4/10
# Average training loss: 0.6932509545644124
# Running Validation...
# Validation Accuracy: 0.49715455271565495
# Validation Loss: 0.6934621188396843
# Epoch 5/10
# Average training loss: 0.6932525463104248
# Running Validation...
# Validation Accuracy: 0.5019968051118211
# Validation Loss: 0.6931621682720063
# Early stopping triggered.
# Training time for this set of hyperparameters: 28.87 seconds
# Training model with hidden_dim=256, n_layers=2, bidirectional=False, dropout=0.3, lr=0.0001
# Epoch 1/10
# Average training loss: 0.6932398972829183
# Running Validation...
# Validation Accuracy: 0.502845447284345
# Validation Loss: 0.6931594753036865
# Epoch 2/10
# Average training loss: 0.6931704241752624
# Running Validation...
# Validation Accuracy: 0.502845447284345
# Validation Loss: 0.6932143491868394
# Epoch 3/10
# Average training loss: 0.6932258440971375
# Running Validation...
# Validation Accuracy: 0.4966553514376997
# Validation Loss: 0.6931604060311668
# Early stopping triggered.
# Training time for this set of hyperparameters: 17.37 seconds
# Best Model Parameters: {'hidden_dim': 128, 'n_layers': 1, 'bidirectional': True, 'dropout': 0.2, 'lr': 0.0001}
# Best Validation Accuracy: 0.5029
# Best Training Time: 16.37 seconds
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-3-73422daa540b> in <cell line: 209>()
#     207
#     208 # Load the best model
# --> 209 best_model.load_state_dict(torch.load('best_lstm_model.pt'))
#     210
#     211 # Evaluate on the test set
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in load_state_dict(self, state_dict, strict, assign)
#    2187
#    2188         if len(error_msgs) > 0:
# -> 2189             raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
#    2190                                self.__class__.__name__, "\n\t".join(error_msgs)))
#    2191         return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for LSTMClassifier:
# 	Missing key(s) in state_dict: "lstm.weight_ih_l0_reverse", "lstm.weight_hh_l0_reverse", "lstm.bias_ih_l0_reverse", "lstm.bias_hh_l0_reverse".
# 	Unexpected key(s) in state_dict: "lstm.weight_ih_l1", "lstm.weight_hh_l1", "lstm.bias_ih_l1", "lstm.bias_hh_l1".
# 	size mismatch for lstm.weight_ih_l0: copying a param with shape torch.Size([1024, 2]) from checkpoint, the shape in current model is torch.Size([512, 2]).
# 	size mismatch for lstm.weight_hh_l0: copying a param with shape torch.Size([1024, 256]) from checkpoint, the shape in current model is torch.Size([512, 128]).
# 	size mismatch for lstm.bias_ih_l0: copying a param with shape torch.Size([1024]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for lstm.bias_hh_l0: copying a param with shape torch.Size([1024]) from checkpoint, the shape in current model is torch.Size([512]).
