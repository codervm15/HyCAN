# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc, precision_score, recall_score, f1_score, accuracy_score
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
import time

if torch.cuda.is_available():
  device = "cuda"
else:
  device = "cpu"

print(f'There are {torch.cuda.device_count()} GPU(s) available.')
print('Device name:', torch.cuda.get_device_name(0))

from google.colab import drive
drive.mount('/content/drive')

# Load dataset
df = pd.read_csv('/content/drive/MyDrive/CAN_Research/CANData/CAND/Traverse/attack-free-1.csv', delimiter=',')
df['datetime'] = df['timestamp']
df['arbitration_id'] = df['arbitration_id'].astype(str).dropna().apply(lambda x: float.fromhex(x))
df['data_field'] = df['data_field'].astype(str).dropna().apply(lambda x: float.fromhex(x))
df['attack'] = 0
df = df.loc[:50000, ['datetime', 'arbitration_id', 'data_field', 'attack']]

dg = pd.read_csv('/content/drive/MyDrive/CAN_Research/CANData/CAND/Traverse/fuzzing-1.csv', delimiter=',')
dg['datetime'] = dg['timestamp']
dg['arbitration_id'] = dg['arbitration_id'].astype(str).dropna().apply(lambda x: float.fromhex(x))
dg['data_field'] = dg['data_field'].astype(str).dropna().apply(lambda x: float.fromhex(x))
dg['attack'] = 1
dg = dg.loc[:50000, ['datetime', 'arbitration_id', 'data_field', 'attack']]

# Feature and label extraction
data = pd.concat([df, dg])
data = shuffle(data)

X = data[['datetime', 'arbitration_id', 'data_field']]
y = data['attack']

# Convert features to float
X = X.astype(float)

# Scaling the features
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# Reshape the features for LSTM
X_scaled = X_scaled.reshape(X_scaled.shape[0], 1, X_scaled.shape[1])

# Split the data into train, validation, and test sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=42)

# Convert to PyTorch tensors
X_train, y_train = torch.tensor(X_train, dtype=torch.float32), torch.tensor(y_train.values, dtype=torch.long)
X_val, y_val = torch.tensor(X_val, dtype=torch.float32), torch.tensor(y_val.values, dtype=torch.long)
X_test, y_test = torch.tensor(X_test, dtype=torch.float32), torch.tensor(y_test.values, dtype=torch.long)

# Create DataLoader
batch_size = 32

train_data = TensorDataset(X_train, y_train)
train_sampler = RandomSampler(train_data)
train_dataloader = DataLoader(train_data, sampler=train_sampler, batch_size=batch_size)

val_data = TensorDataset(X_val, y_val)
val_sampler = SequentialSampler(val_data)
val_dataloader = DataLoader(val_data, sampler=val_sampler, batch_size=batch_size)

test_data = TensorDataset(X_test, y_test)
test_sampler = SequentialSampler(test_data)
test_dataloader = DataLoader(test_data, sampler=test_sampler, batch_size=batch_size)

# Define LSTM model
class LSTMClassifier(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, n_layers, bidirectional, dropout):
        super(LSTMClassifier, self).__init__()
        self.lstm = nn.LSTM(input_dim, hidden_dim, num_layers=n_layers, bidirectional=bidirectional, dropout=(dropout if n_layers > 1 else 0), batch_first=True)
        self.fc = nn.Linear(hidden_dim * 2 if bidirectional else hidden_dim, output_dim)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        h0, c0 = self.init_hidden(x.size(0))
        out, _ = self.lstm(x, (h0, c0))
        out = self.fc(self.dropout(out[:, -1, :]))
        return out

    def init_hidden(self, batch_size):
        h0 = torch.zeros(self.lstm.num_layers * 2 if self.lstm.bidirectional else self.lstm.num_layers, batch_size, self.lstm.hidden_size).to(device)
        c0 = torch.zeros(self.lstm.num_layers * 2 if self.lstm.bidirectional else self.lstm.num_layers, batch_size, self.lstm.hidden_size).to(device)
        return h0, c0

# Hyperparameter tuning
hidden_dims = [128, 256]
n_layers_list = [1, 2]
bidirectional_list = [True, False]
dropout_rates = [0.2, 0.3]
learning_rates = [0.001, 0.0001]

best_model = None
best_score = 0
best_params = {}
best_training_time = 0

for hidden_dim in hidden_dims:
    for n_layers in n_layers_list:
        for bidirectional in bidirectional_list:
            for dropout in dropout_rates:
                for lr in learning_rates:
                    print(f"Training model with hidden_dim={hidden_dim}, n_layers={n_layers}, bidirectional={bidirectional}, dropout={dropout}, lr={lr}")
                    model = LSTMClassifier(input_dim=X_train.shape[2], hidden_dim=hidden_dim, output_dim=2, n_layers=n_layers, bidirectional=bidirectional, dropout=dropout)
                    model.to(device)

                    optimizer = optim.Adam(model.parameters(), lr=lr)
                    criterion = nn.CrossEntropyLoss()

                    patience = 2
                    early_stopping_counter = 0
                    best_validation_loss = float('inf')
                    loss_values, validation_loss_values = [], []

                    training_start_time = time.time()

                    for epoch_i in range(0, 10):  # Reduced epochs for faster tuning
                        print(f"Epoch {epoch_i + 1}/10")
                        model.train()
                        total_loss = 0

                        for step, batch in enumerate(train_dataloader):
                            b_input, b_labels = batch
                            b_input, b_labels = b_input.to(device), b_labels.to(device)

                            model.zero_grad()
                            outputs = model(b_input)
                            loss = criterion(outputs, b_labels)
                            total_loss += loss.item()

                            loss.backward()
                            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
                            optimizer.step()

                        avg_train_loss = total_loss / len(train_dataloader)
                        loss_values.append(avg_train_loss)
                        print(f'Average training loss: {avg_train_loss}')

                        print('Running Validation...')
                        model.eval()
                        eval_loss, eval_accuracy = 0, 0
                        nb_eval_steps, nb_eval_examples = 0, 0

                        for batch in val_dataloader:
                            b_input, b_labels = batch
                            b_input, b_labels = b_input.to(device), b_labels.to(device)

                            with torch.no_grad():
                                outputs = model(b_input)
                            loss = criterion(outputs, b_labels)
                            eval_loss += loss.item()
                            preds_flat = np.argmax(outputs.detach().cpu().numpy(), axis=1).flatten()
                            labels_flat = b_labels.cpu().numpy().flatten()
                            eval_accuracy += np.sum(preds_flat == labels_flat) / len(labels_flat)
                            nb_eval_steps += 1

                        avg_val_accuracy = eval_accuracy / nb_eval_steps
                        avg_val_loss = eval_loss / nb_eval_steps
                        validation_loss_values.append(avg_val_loss)
                        print(f'Validation Accuracy: {avg_val_accuracy}')
                        print(f'Validation Loss: {avg_val_loss}')

                        if avg_val_loss < best_validation_loss:
                            best_validation_loss = avg_val_loss
                            early_stopping_counter = 0
                            torch.save(model.state_dict(), 'best_lstm_model.pt')
                        else:
                            early_stopping_counter += 1

                        if early_stopping_counter >= patience:
                            print('Early stopping triggered.')
                            break

                    training_end_time = time.time()
                    training_time = training_end_time - training_start_time
                    print(f'Training time for this set of hyperparameters: {training_time:.2f} seconds')

                    if avg_val_accuracy > best_score:
                        best_score = avg_val_accuracy
                        best_model = model
                        best_params = {
                            'hidden_dim': hidden_dim,
                            'n_layers': n_layers,
                            'bidirectional': bidirectional,
                            'dropout': dropout,
                            'lr': lr
                        }
                        best_training_time = training_time

print(f"Best Model Parameters: {best_params}")
print(f"Best Validation Accuracy: {best_score:.4f}")
print(f"Best Training Time: {best_training_time:.2f} seconds")

# Load the best model
best_model.load_state_dict(torch.load('best_lstm_model.pt'))

# Evaluate on the test set
best_model.eval()
predictions, true_labels = [], []
test_start_time = time.time()

for batch in test_dataloader:
    b_input, b_labels = batch
    b_input, b_labels = b_input.to(device), b_labels.to(device)

    with torch.no_grad():
        outputs = best_model(b_input)

    logits = outputs.detach().cpu().numpy()
    label_ids = b_labels.to('cpu').numpy()
    predictions.extend(np.argmax(logits, axis=1).flatten())
    true_labels.extend(label_ids.flatten())

test_end_time = time.time()
test_time = test_end_time - test_start_time

print(f"Test complete! Total prediction time: {test_time:.2f} seconds")

# Classification report
print(classification_report(true_labels, predictions, digits=4))

# Confusion matrix
cm = confusion_matrix(true_labels, predictions)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# ROC curve
fpr, tpr, _ = roc_curve(true_labels, predictions)
roc_auc = auc(fpr, tpr)
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='grey', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# Bar plot for metrics
accuracy = accuracy_score(true_labels, predictions)
precision = precision_score(true_labels, predictions)
recall = recall_score(true_labels, predictions)
f1 = f1_score(true_labels, predictions)

metrics = {'Accuracy': accuracy, 'Precision': precision, 'Recall': recall, 'F1 Score': f1}
plt.figure(figsize=(8, 6))
plt.bar(metrics.keys(), metrics.values())
plt.ylim(0, 1)
plt.title('Metrics')
plt.show()

# Plot the learning curve
sns.set(style='darkgrid')
sns.set(font_scale=1.5)
plt.rcParams["figure.figsize"] = (12, 6)
plt.plot(loss_values, 'b-o', label="training loss")
plt.plot(validation_loss_values, 'r-o', label="validation loss")
plt.title("Learning curve")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.show()
# Out:
# There are 1 GPU(s) available.
# Device name: NVIDIA RTX A5000
# Training model with hidden_dim=128, n_layers=1, bidirectional=True, dropout=0.2, lr=0.001
# Epoch 1/10
# Average training loss: 0.6933855813026428
# Running Validation...
# Validation Accuracy: 0.49770367412140576
# Validation Loss: 0.6931800048191327
# Epoch 2/10
# Average training loss: 0.6932050888061524
# Running Validation...
# Validation Accuracy: 0.5027955271565495
# Validation Loss: 0.6931573771440183
# Epoch 3/10
# Average training loss: 0.6932553988138834
# Running Validation...
# Validation Accuracy: 0.5020966453674122
# Validation Loss: 0.6931530813249155
# Epoch 4/10
# Average training loss: 0.6932395851771037
# Running Validation...
# Validation Accuracy: 0.4978035143769968
# Validation Loss: 0.6934087462128161
# Epoch 5/10
# Average training loss: 0.6932296658833822
# Running Validation...
# Validation Accuracy: 0.501048322683706
# Validation Loss: 0.693105591086153
# Epoch 6/10
# Average training loss: 0.6932440911610921
# Running Validation...
# Validation Accuracy: 0.5001996805111821
# Validation Loss: 0.6931626890033198
# Epoch 7/10
# Average training loss: 0.6932169201850891
# Running Validation...
# Validation Accuracy: 0.49995007987220447
# Validation Loss: 0.6931559539641055
# Early stopping triggered.
# Training time for this set of hyperparameters: 56.81 seconds
# Training model with hidden_dim=128, n_layers=1, bidirectional=True, dropout=0.2, lr=0.0001
# Epoch 1/10
# Average training loss: 0.6931817072232564
# Running Validation...
# Validation Accuracy: 0.4967052715654952
# Validation Loss: 0.6931504117795073
# Epoch 2/10
# Average training loss: 0.6931583913167317
# Running Validation...
# Validation Accuracy: 0.4978035143769968
# Validation Loss: 0.6932348786070704
# Epoch 3/10
# Average training loss: 0.6931798397699992
# Running Validation...
# Validation Accuracy: 0.5029952076677316
# Validation Loss: 0.693122370555378
# Epoch 4/10
# Average training loss: 0.6931972497622172
# Running Validation...
# Validation Accuracy: 0.5060902555910544
# Validation Loss: 0.6931371984009544
# Epoch 5/10
# Average training loss: 0.693135503133138
# Running Validation...
# Validation Accuracy: 0.5037939297124601
# Validation Loss: 0.6931188008465325
# Epoch 6/10
# Average training loss: 0.6931753978411357
# Running Validation...
# Validation Accuracy: 0.4992511980830671
# Validation Loss: 0.6931468950102504
# Epoch 7/10
# Average training loss: 0.6931729323387146
# Running Validation...
# Validation Accuracy: 0.4998502396166134
# Validation Loss: 0.6931639840237249
# Early stopping triggered.
# Training time for this set of hyperparameters: 52.32 seconds
# Training model with hidden_dim=128, n_layers=1, bidirectional=True, dropout=0.3, lr=0.001
# Epoch 1/10
# Average training loss: 0.6934050316810608
# Running Validation...
# Validation Accuracy: 0.5021964856230032
# Validation Loss: 0.693440065692408
# Epoch 2/10
# Average training loss: 0.6933073630332947
# Running Validation...
# Validation Accuracy: 0.4978035143769968
# Validation Loss: 0.6934135782832916
# Epoch 3/10
# Average training loss: 0.6932937793095907
# Running Validation...
# Validation Accuracy: 0.4978035143769968
# Validation Loss: 0.693166909126428
# Epoch 4/10
# Average training loss: 0.6932473061879476
# Running Validation...
# Validation Accuracy: 0.4978035143769968
# Validation Loss: 0.6931610101708969
# Epoch 5/10
# Average training loss: 0.6932612144788106
# Running Validation...
# Validation Accuracy: 0.4978035143769968
# Validation Loss: 0.6933322912587906
# Epoch 6/10
# Average training loss: 0.6932724342981974
# Running Validation...
# Validation Accuracy: 0.5009984025559105
# Validation Loss: 0.6931226858125327
# Epoch 7/10
# Average training loss: 0.6932554243723551
# Running Validation...
# Validation Accuracy: 0.5015475239616614
# Validation Loss: 0.693133389321379
# Epoch 8/10
# Average training loss: 0.6931764701207479
# Running Validation...
# Validation Accuracy: 0.4978035143769968
# Validation Loss: 0.6934363070768289
# Early stopping triggered.
# Training time for this set of hyperparameters: 61.09 seconds
# Training model with hidden_dim=128, n_layers=1, bidirectional=True, dropout=0.3, lr=0.0001
# Epoch 1/10
# Average training loss: 0.693263634300232
# Running Validation...
# Validation Accuracy: 0.4978035143769968
# Validation Loss: 0.6932221772000432
# Epoch 2/10
# Average training loss: 0.693210738658905
# Running Validation...
# Validation Accuracy: 0.5056908945686901
# Validation Loss: 0.6931261354551529
# Epoch 3/10
# Average training loss: 0.6931828806559245
# Running Validation...
# Validation Accuracy: 0.5059904153354633
# Validation Loss: 0.6931165839536503
# Epoch 4/10
# Average training loss: 0.6931508993148804
# Running Validation...
# Validation Accuracy: 0.4978035143769968
# Validation Loss: 0.6932288877689801
# Epoch 5/10
# Average training loss: 0.6931577871958414
# Running Validation...
# Validation Accuracy: 0.4978035143769968
# Validation Loss: 0.6933513841689966
# Early stopping triggered.
# Training time for this set of hyperparameters: 40.51 seconds
# Training model with hidden_dim=128, n_layers=1, bidirectional=False, dropout=0.2, lr=0.001
# Epoch 1/10
# Average training loss: 0.6932718141237895
# Running Validation...
# Validation Accuracy: 0.5012979233226837
# Validation Loss: 0.6931561283029306
# Epoch 2/10
# Average training loss: 0.6933055735905965
# Running Validation...
# Validation Accuracy: 0.4978035143769968
# Validation Loss: 0.6934262310354092
# Epoch 3/10
# Average training loss: 0.6932681604067484
# Running Validation...
# Validation Accuracy: 0.5021964856230032
# Validation Loss: 0.6931322642599052
# Epoch 4/10
# Average training loss: 0.6932382383028666
# Running Validation...
# Validation Accuracy: 0.5047923322683706
# Validation Loss: 0.693136528658029
# Epoch 5/10
# Average training loss: 0.6932256001154582
# Running Validation...
# Validation Accuracy: 0.502745607028754
# Validation Loss: 0.693115788241164
# Epoch 6/10
# Average training loss: 0.6931853094418844
# Running Validation...
# Validation Accuracy: 0.5015475239616614
# Validation Loss: 0.6931120340054789
# Epoch 7/10
# Average training loss: 0.6932129695574443
# Running Validation...
# Validation Accuracy: 0.506439696485623
# Validation Loss: 0.693086284894151
# Epoch 8/10
# Average training loss: 0.6932469679196676
# Running Validation...
# Validation Accuracy: 0.49900159744408945
# Validation Loss: 0.6931610730128547
# Epoch 9/10
# Average training loss: 0.6931831971168518
# Running Validation...
# Validation Accuracy: 0.4978035143769968
# Validation Loss: 0.6933224091705043
# Early stopping triggered.
# Training time for this set of hyperparameters: 50.56 seconds
# Training model with hidden_dim=128, n_layers=1, bidirectional=False, dropout=0.2, lr=0.0001
# Epoch 1/10
# Average training loss: 0.6933444523493449
# Running Validation...
# Validation Accuracy: 0.4978035143769968
# Validation Loss: 0.6931863634731061
# Epoch 2/10
# Average training loss: 0.6931804003079732
# Running Validation...
# Validation Accuracy: 0.5149261182108626
# Validation Loss: 0.693138836576535
# Epoch 3/10
# Average training loss: 0.6931966783205669
# Running Validation...
# Validation Accuracy: 0.4978035143769968
# Validation Loss: 0.693229180460159
# Epoch 4/10
# Average training loss: 0.6931548543612163
# Running Validation...
# Validation Accuracy: 0.4984025559105431
# Validation Loss: 0.6931468987236389
# Early stopping triggered.
# Training time for this set of hyperparameters: 29.57 seconds
# Training model with hidden_dim=128, n_layers=1, bidirectional=False, dropout=0.3, lr=0.001
# Epoch 1/10
# Average training loss: 0.6932789793332418
# Running Validation...
# Validation Accuracy: 0.4978035143769968
# Validation Loss: 0.693577336617552
# Epoch 2/10
# Average training loss: 0.6933000719388326
# Running Validation...
# Validation Accuracy: 0.4978035143769968
# Validation Loss: 0.6932127050127084
# Epoch 3/10
# Average training loss: 0.6932528752326965
# Running Validation...
# Validation Accuracy: 0.5003993610223643
# Validation Loss: 0.6931041334383785
# Epoch 4/10
# Average training loss: 0.6932392220815022
# Running Validation...
# Validation Accuracy: 0.4978035143769968
# Validation Loss: 0.6934855984994017
# Epoch 5/10
# Average training loss: 0.6932760674158732
# Running Validation...
# Validation Accuracy: 0.5023961661341853
# Validation Loss: 0.6931097360845572
# Early stopping triggered.
# Training time for this set of hyperparameters: 25.63 seconds
# Training model with hidden_dim=128, n_layers=1, bidirectional=False, dropout=0.3, lr=0.0001
# Epoch 1/10
# Average training loss: 0.6932483670552572
# Running Validation...
# Validation Accuracy: 0.4977535942492013
# Validation Loss: 0.6931599311935254
# Epoch 2/10
# Average training loss: 0.6931591546376547
# Running Validation...
# Validation Accuracy: 0.5055411341853036
# Validation Loss: 0.6931254628557748
# Epoch 3/10
# Average training loss: 0.693179367351532
# Running Validation...
# Validation Accuracy: 0.5078873801916933
# Validation Loss: 0.6931237593626443
# Epoch 4/10
# Average training loss: 0.6931595547040303
# Running Validation...
# Validation Accuracy: 0.5069888178913738
# Validation Loss: 0.6931211117167062
# Epoch 5/10
# Average training loss: 0.6931010087013245
# Running Validation...
# Validation Accuracy: 0.5014476837060703
# Validation Loss: 0.6931136928427334
# Epoch 6/10
# Average training loss: 0.6931594701131185
# Running Validation...
# Validation Accuracy: 0.5003494408945687
# Validation Loss: 0.6931122171040922
# Epoch 7/10
# Average training loss: 0.6931516752243042
# Running Validation...
# Validation Accuracy: 0.5014476837060703
# Validation Loss: 0.6931686667017282
# Epoch 8/10
# Average training loss: 0.6931577781041464
# Running Validation...
# Validation Accuracy: 0.5065894568690096
# Validation Loss: 0.6931257958229358
# Early stopping triggered.
# Training time for this set of hyperparameters: 48.83 seconds
# Training model with hidden_dim=128, n_layers=2, bidirectional=True, dropout=0.2, lr=0.001
# Epoch 1/10
# Average training loss: 0.6934190436999003
# Running Validation...
# Validation Accuracy: 0.4978035143769968
# Validation Loss: 0.6932344935572566
# Epoch 2/10
# Average training loss: 0.6932386578559876
# Running Validation...
# Validation Accuracy: 0.5021964856230032
# Validation Loss: 0.6933393648828561
# Epoch 3/10
# Average training loss: 0.6932579388936361
# Running Validation...
# Validation Accuracy: 0.5021964856230032
# Validation Loss: 0.6935059419645669
# Early stopping triggered.
# Training time for this set of hyperparameters: 27.26 seconds
# Training model with hidden_dim=128, n_layers=2, bidirectional=True, dropout=0.2, lr=0.0001
# Epoch 1/10
# Average training loss: 0.6931648952802022
# Running Validation...
# Validation Accuracy: 0.5021964856230032
# Validation Loss: 0.6932444263951847
# Epoch 2/10
# Average training loss: 0.693229274113973
# Running Validation...
# Validation Accuracy: 0.49805311501597443
# Validation Loss: 0.6931527573079728
# Epoch 3/10
# Average training loss: 0.6931803517977396
# Running Validation...
# Validation Accuracy: 0.5042432108626198
# Validation Loss: 0.693118650025834
# Epoch 4/10
# Average training loss: 0.6931879146893819
# Running Validation...
# Validation Accuracy: 0.5048921725239617
# Validation Loss: 0.6931178396502242
# Epoch 5/10
# Average training loss: 0.6931871466636658
# Running Validation...
# Validation Accuracy: 0.4978035143769968
# Validation Loss: 0.6932023214265561
# Epoch 6/10
# Average training loss: 0.6931385031382243
# Running Validation...
# Validation Accuracy: 0.5020966453674122
# Validation Loss: 0.693116165864201
# Epoch 7/10
# Average training loss: 0.6931640244483948
# Running Validation...
# Validation Accuracy: 0.5052416134185304
# Validation Loss: 0.6931260385261938
# Epoch 8/10
# Average training loss: 0.6931563911437988
# Running Validation...
# Validation Accuracy: 0.5037440095846646
# Validation Loss: 0.6931231717903393
# Early stopping triggered.
# Training time for this set of hyperparameters: 79.67 seconds
# Training model with hidden_dim=128, n_layers=2, bidirectional=True, dropout=0.3, lr=0.001
# Epoch 1/10
# Average training loss: 0.6933896340370178
# Running Validation...
# Validation Accuracy: 0.4978035143769968
# Validation Loss: 0.69361664435734
# Epoch 2/10
# Average training loss: 0.6933192549705506
# Running Validation...
# Validation Accuracy: 0.4993011182108626
# Validation Loss: 0.6931199927489978
# Epoch 3/10
# Average training loss: 0.693263220500946
# Running Validation...
# Validation Accuracy: 0.5048422523961661
# Validation Loss: 0.6931392759941637
# Epoch 4/10
# Average training loss: 0.6932644148190816
# Running Validation...
# Validation Accuracy: 0.4978035143769968
# Validation Loss: 0.6932053789734459
# Early stopping triggered.
# Training time for this set of hyperparameters: 39.95 seconds
# Training model with hidden_dim=128, n_layers=2, bidirectional=True, dropout=0.3, lr=0.0001
# Epoch 1/10
# Average training loss: 0.6932024494171143
# Running Validation...
# Validation Accuracy: 0.4978035143769968
# Validation Loss: 0.6933624146464533
# Epoch 2/10
# Average training loss: 0.6931688737869263
# Running Validation...
# Validation Accuracy: 0.4978035143769968
# Validation Loss: 0.6932137878938985
# Epoch 3/10
# Average training loss: 0.6931397647857666
# Running Validation...
# Validation Accuracy: 0.4978035143769968
# Validation Loss: 0.6934285499036502
# Epoch 4/10
# Average training loss: 0.6931554971059164
# Running Validation...
# Validation Accuracy: 0.50189696485623
# Validation Loss: 0.6931357586536163
# Epoch 5/10
# Average training loss: 0.6931818125724792
# Running Validation...
# Validation Accuracy: 0.5030950479233227
# Validation Loss: 0.6931438625049287
# Epoch 6/10
# Average training loss: 0.6931935882250468
# Running Validation...
# Validation Accuracy: 0.5021465654952076
# Validation Loss: 0.693120666490957
# Epoch 7/10
# Average training loss: 0.6931874389648438
# Running Validation...
# Validation Accuracy: 0.5030451277955271
# Validation Loss: 0.6931129015101412
# Epoch 8/10
# Average training loss: 0.6931720124880473
# Running Validation...
# Validation Accuracy: 0.5031948881789138
# Validation Loss: 0.6931155724837758
# Epoch 9/10
# Average training loss: 0.6932050035476685
# Running Validation...
# Validation Accuracy: 0.4978035143769968
# Validation Loss: 0.6931992971097318
# Early stopping triggered.
# Training time for this set of hyperparameters: 77.29 seconds
# Training model with hidden_dim=128, n_layers=2, bidirectional=False, dropout=0.2, lr=0.001
# Epoch 1/10
# Average training loss: 0.6932755211194356
# Running Validation...
# Validation Accuracy: 0.5021964856230032
# Validation Loss: 0.6931641090411348
# Epoch 2/10
# Average training loss: 0.6932253932317098
# Running Validation...
# Validation Accuracy: 0.5021964856230032
# Validation Loss: 0.6931512870918066
# Epoch 3/10
# Average training loss: 0.6931928309440613
# Running Validation...
# Validation Accuracy: 0.4978035143769968
# Validation Loss: 0.6933519851666289
# Epoch 4/10
# Average training loss: 0.6932287522633871
# Running Validation...
# Validation Accuracy: 0.49845247603833864
# Validation Loss: 0.6931514401976674
# Early stopping triggered.
# Training time for this set of hyperparameters: 28.34 seconds
# Training model with hidden_dim=128, n_layers=2, bidirectional=False, dropout=0.2, lr=0.0001
# Epoch 1/10
# Average training loss: 0.693232871723175
# Running Validation...
# Validation Accuracy: 0.4978035143769968
# Validation Loss: 0.693221973534971
# Epoch 2/10
# Average training loss: 0.6932008583068847
# Running Validation...
# Validation Accuracy: 0.4978035143769968
# Validation Loss: 0.693178145554119
# Epoch 3/10
# Average training loss: 0.6931826098759969
# Running Validation...
# Validation Accuracy: 0.4978035143769968
# Validation Loss: 0.6932348628965811
# Epoch 4/10
# Average training loss: 0.6931568230946858
# Running Validation...
# Validation Accuracy: 0.506439696485623
# Validation Loss: 0.6931298634114738
# Epoch 5/10
# Average training loss: 0.6931611113230387
# Running Validation...
# Validation Accuracy: 0.5008985623003195
# Validation Loss: 0.6931184674985111
# Epoch 6/10
# Average training loss: 0.6931721971829732
# Running Validation...
# Validation Accuracy: 0.5009984025559105
# Validation Loss: 0.6931522820894711
# Epoch 7/10
# Average training loss: 0.6931569838523864
# Running Validation...
# Validation Accuracy: 0.5037440095846646
# Validation Loss: 0.6931239664554596
# Early stopping triggered.
# Training time for this set of hyperparameters: 47.34 seconds
# Training model with hidden_dim=128, n_layers=2, bidirectional=False, dropout=0.3, lr=0.001
# Epoch 1/10
# Average training loss: 0.6933279754956563
# Running Validation...
# Validation Accuracy: 0.5023961661341853
# Validation Loss: 0.693124433771109
# Epoch 2/10
# Average training loss: 0.6932794197082519
# Running Validation...
# Validation Accuracy: 0.4978035143769968
# Validation Loss: 0.6932990413885147
# Epoch 3/10
# Average training loss: 0.6932740729649861
# Running Validation...
# Validation Accuracy: 0.4978035143769968
# Validation Loss: 0.6932422653935588
# Early stopping triggered.
# Training time for this set of hyperparameters: 13.86 seconds
# Training model with hidden_dim=128, n_layers=2, bidirectional=False, dropout=0.3, lr=0.0001
# Epoch 1/10
# Average training loss: 0.6931145248095194
# Running Validation...
# Validation Accuracy: 0.5021964856230032
# Validation Loss: 0.693174836448968
# Epoch 2/10
# Average training loss: 0.6932062355677286
# Running Validation...
# Validation Accuracy: 0.5085862619808307
# Validation Loss: 0.6931416226652103
# Epoch 3/10
# Average training loss: 0.6931937796910603
# Running Validation...
# Validation Accuracy: 0.4978035143769968
# Validation Loss: 0.6932029114744533
# Epoch 4/10
# Average training loss: 0.6931551097869874
# Running Validation...
# Validation Accuracy: 0.5069388977635783
# Validation Loss: 0.6931393447394569
# Epoch 5/10
# Average training loss: 0.693154114596049
# Running Validation...
# Validation Accuracy: 0.4978035143769968
# Validation Loss: 0.6932393551444094
# Epoch 6/10
# Average training loss: 0.6931718934377035
# Running Validation...
# Validation Accuracy: 0.4978035143769968
# Validation Loss: 0.6932782336545829
# Early stopping triggered.
# Training time for this set of hyperparameters: 39.99 seconds
# Training model with hidden_dim=256, n_layers=1, bidirectional=True, dropout=0.2, lr=0.001
# Epoch 1/10
# Average training loss: 0.6933364744822185
# Running Validation...
# Validation Accuracy: 0.4978035143769968
# Validation Loss: 0.6931919977306938
# Epoch 2/10
# Average training loss: 0.6933306621233623
# Running Validation...
# Validation Accuracy: 0.5041932907348243
# Validation Loss: 0.6931192525469076
# Epoch 3/10
# Average training loss: 0.6932469608624776
# Running Validation...
# Validation Accuracy: 0.4978035143769968
# Validation Loss: 0.6941908584616054
# Epoch 4/10
# Average training loss: 0.6932953662872314
# Running Validation...
# Validation Accuracy: 0.49790335463258784
# Validation Loss: 0.6931604041268651
# Early stopping triggered.
# Training time for this set of hyperparameters: 34.57 seconds
# Training model with hidden_dim=256, n_layers=1, bidirectional=True, dropout=0.2, lr=0.0001
# Epoch 1/10
# Average training loss: 0.6932027854601542
# Running Validation...
# Validation Accuracy: 0.4978035143769968
# Validation Loss: 0.6931861872299792
# Epoch 2/10
# Average training loss: 0.6932031359036763
# Running Validation...
# Validation Accuracy: 0.4978035143769968
# Validation Loss: 0.6932034381091023
# Epoch 3/10
# Average training loss: 0.6931755515098572
# Running Validation...
# Validation Accuracy: 0.5014476837060703
# Validation Loss: 0.6931263571158766
# Epoch 4/10
# Average training loss: 0.6931489814122518
# Running Validation...
# Validation Accuracy: 0.4980031948881789
# Validation Loss: 0.6931717983259561
# Epoch 5/10
# Average training loss: 0.6931773331006368
# Running Validation...
# Validation Accuracy: 0.5003993610223643
# Validation Loss: 0.6931530259097346
# Early stopping triggered.
# Training time for this set of hyperparameters: 42.33 seconds
# Training model with hidden_dim=256, n_layers=1, bidirectional=True, dropout=0.3, lr=0.001
# Epoch 1/10
# Average training loss: 0.6934595062891642
# Running Validation...
# Validation Accuracy: 0.5039436900958466
# Validation Loss: 0.6931081063831195
# Epoch 2/10
# Average training loss: 0.6932985330263773
# Running Validation...
# Validation Accuracy: 0.4978035143769968
# Validation Loss: 0.6937124235942341
# Epoch 3/10
# Average training loss: 0.6933556505203247
# Running Validation...
# Validation Accuracy: 0.5029952076677316
# Validation Loss: 0.6931194745884917
# Early stopping triggered.
# Training time for this set of hyperparameters: 26.00 seconds
# Training model with hidden_dim=256, n_layers=1, bidirectional=True, dropout=0.3, lr=0.0001
# Epoch 1/10
# Average training loss: 0.6932166030248006
# Running Validation...
# Validation Accuracy: 0.4991014376996805
# Validation Loss: 0.6931496806228503
# Epoch 2/10
# Average training loss: 0.6931601664543152
# Running Validation...
# Validation Accuracy: 0.5049920127795527
# Validation Loss: 0.6931227003804411
# Epoch 3/10
# Average training loss: 0.693191941579183
# Running Validation...
# Validation Accuracy: 0.5003494408945687
# Validation Loss: 0.6931195204821639
# Epoch 4/10
# Average training loss: 0.6931497928937276
# Running Validation...
# Validation Accuracy: 0.5005990415335463
# Validation Loss: 0.6931350343524457
# Epoch 5/10
# Average training loss: 0.6931785026550293
# Running Validation...
# Validation Accuracy: 0.49915135782747605
# Validation Loss: 0.6931638662426617
# Early stopping triggered.
# Training time for this set of hyperparameters: 38.67 seconds
# Training model with hidden_dim=256, n_layers=1, bidirectional=False, dropout=0.2, lr=0.001
# Epoch 1/10
# Average training loss: 0.6933564430554708
# Running Validation...
# Validation Accuracy: 0.4977535942492013
# Validation Loss: 0.6931841820954515
# Epoch 2/10
# Average training loss: 0.6932550115267436
# Running Validation...
# Validation Accuracy: 0.5021964856230032
# Validation Loss: 0.6932190867087331
# Epoch 3/10
# Average training loss: 0.693275175412496
# Running Validation...
# Validation Accuracy: 0.4978035143769968
# Validation Loss: 0.6932111284412896
# Early stopping triggered.
# Training time for this set of hyperparameters: 17.85 seconds
# Training model with hidden_dim=256, n_layers=1, bidirectional=False, dropout=0.2, lr=0.0001
# Epoch 1/10
# Average training loss: 0.6932687840779622
# Running Validation...
# Validation Accuracy: 0.49940095846645366
# Validation Loss: 0.6932066503805093
# Epoch 2/10
# Average training loss: 0.6931802391370138
# Running Validation...
# Validation Accuracy: 0.49915135782747605
# Validation Loss: 0.6931953268310133
# Epoch 3/10
# Average training loss: 0.6931626759847005
# Running Validation...
# Validation Accuracy: 0.5076377795527156
# Validation Loss: 0.69314539832429
# Epoch 4/10
# Average training loss: 0.6931364760398865
# Running Validation...
# Validation Accuracy: 0.4988019169329074
# Validation Loss: 0.693129072554957
# Epoch 5/10
# Average training loss: 0.6931687923749288
# Running Validation...
# Validation Accuracy: 0.4978035143769968
# Validation Loss: 0.6933303296375579
# Epoch 6/10
# Average training loss: 0.6931730441093444
# Running Validation...
# Validation Accuracy: 0.5049420926517572
# Validation Loss: 0.6931341943649438
# Early stopping triggered.
# Training time for this set of hyperparameters: 44.55 seconds
# Training model with hidden_dim=256, n_layers=1, bidirectional=False, dropout=0.3, lr=0.001
# Epoch 1/10
# Average training loss: 0.693374095694224
# Running Validation...
# Validation Accuracy: 0.5012979233226837
# Validation Loss: 0.6931186616420746
# Epoch 2/10
# Average training loss: 0.6932757497151693
# Running Validation...
# Validation Accuracy: 0.5031948881789138
# Validation Loss: 0.6931757263291758
# Epoch 3/10
# Average training loss: 0.6932432232220967
# Running Validation...
# Validation Accuracy: 0.5021964856230032
# Validation Loss: 0.6936277319638493
# Early stopping triggered.
# Training time for this set of hyperparameters: 22.19 seconds
# Training model with hidden_dim=256, n_layers=1, bidirectional=False, dropout=0.3, lr=0.0001
# Epoch 1/10
# Average training loss: 0.6931972083727519
# Running Validation...
# Validation Accuracy: 0.49645567092651754
# Validation Loss: 0.6931665952974996
# Epoch 2/10
# Average training loss: 0.6931657131195068
# Running Validation...
# Validation Accuracy: 0.49795327476038337
# Validation Loss: 0.6931908156353825
# Epoch 3/10
# Average training loss: 0.6931304898897807
# Running Validation...
# Validation Accuracy: 0.4978035143769968
# Validation Loss: 0.693274475229434
# Early stopping triggered.
# Training time for this set of hyperparameters: 21.46 seconds
# Training model with hidden_dim=256, n_layers=2, bidirectional=True, dropout=0.2, lr=0.001
# Epoch 1/10
# Average training loss: 0.6933391383488973
# Running Validation...
# Validation Accuracy: 0.4974540734824281
# Validation Loss: 0.6932412287869012
# Epoch 2/10
# Average training loss: 0.6932450679779053
# Running Validation...
# Validation Accuracy: 0.4978035143769968
# Validation Loss: 0.6932769849087103
# Epoch 3/10
# Average training loss: 0.6932912063280742
# Running Validation...
# Validation Accuracy: 0.4978035143769968
# Validation Loss: 0.6931952505637282
# Epoch 4/10
# Average training loss: 0.69325059521993
# Running Validation...
# Validation Accuracy: 0.4978035143769968
# Validation Loss: 0.693291980618486
# Epoch 5/10
# Average training loss: 0.6932686411539714
# Running Validation...
# Validation Accuracy: 0.5031449680511182
# Validation Loss: 0.693132473066592
# Epoch 6/10
# Average training loss: 0.6932587737401327
# Running Validation...
# Validation Accuracy: 0.5021964856230032
# Validation Loss: 0.6931716985405444
# Epoch 7/10
# Average training loss: 0.6932658352851868
# Running Validation...
# Validation Accuracy: 0.5019468849840255
# Validation Loss: 0.693136205402807
# Early stopping triggered.
# Training time for this set of hyperparameters: 66.82 seconds
# Training model with hidden_dim=256, n_layers=2, bidirectional=True, dropout=0.2, lr=0.0001
# Epoch 1/10
# Average training loss: 0.6932021560986836
# Running Validation...
# Validation Accuracy: 0.4978035143769968
# Validation Loss: 0.6931972684570775
# Epoch 2/10
# Average training loss: 0.6932278641064962
# Running Validation...
# Validation Accuracy: 0.4978035143769968
# Validation Loss: 0.6932421834133684
# Epoch 3/10
# Average training loss: 0.6931785044670105
# Running Validation...
# Validation Accuracy: 0.5009984025559105
# Validation Loss: 0.6931243617885029
# Epoch 4/10
# Average training loss: 0.6931925399144491
# Running Validation...
# Validation Accuracy: 0.5001996805111821
# Validation Loss: 0.6931530072475774
# Epoch 5/10
# Average training loss: 0.6931746579170227
# Running Validation...
# Validation Accuracy: 0.502645766773163
# Validation Loss: 0.6931357663660385
# Early stopping triggered.
# Training time for this set of hyperparameters: 53.39 seconds
# Training model with hidden_dim=256, n_layers=2, bidirectional=True, dropout=0.3, lr=0.001
# Epoch 1/10
# Average training loss: 0.6934488693555196
# Running Validation...
# Validation Accuracy: 0.4978035143769968
# Validation Loss: 0.6932202948929783
# Epoch 2/10
# Average training loss: 0.693381018447876
# Running Validation...
# Validation Accuracy: 0.49845247603833864
# Validation Loss: 0.6932664662123488
# Epoch 3/10
# Average training loss: 0.6933118416468302
# Running Validation...
# Validation Accuracy: 0.4978035143769968
# Validation Loss: 0.6932482789880552
# Early stopping triggered.
# Training time for this set of hyperparameters: 29.33 seconds
# Training model with hidden_dim=256, n_layers=2, bidirectional=True, dropout=0.3, lr=0.0001
# Epoch 1/10
# Average training loss: 0.6932231839815776
# Running Validation...
# Validation Accuracy: 0.4978035143769968
# Validation Loss: 0.693195494028707
# Epoch 2/10
# Average training loss: 0.6932243021329244
# Running Validation...
# Validation Accuracy: 0.503694089456869
# Validation Loss: 0.6931214867689358
# Epoch 3/10
# Average training loss: 0.6931784266471863
# Running Validation...
# Validation Accuracy: 0.502845447284345
# Validation Loss: 0.6931677656813552
# Epoch 4/10
# Average training loss: 0.6932380656878153
# Running Validation...
# Validation Accuracy: 0.5006988817891374
# Validation Loss: 0.6931205767031294
# Epoch 5/10
# Average training loss: 0.6931802182833353
# Running Validation...
# Validation Accuracy: 0.5023961661341853
# Validation Loss: 0.6931227667453571
# Epoch 6/10
# Average training loss: 0.6931999192237854
# Running Validation...
# Validation Accuracy: 0.49875199680511184
# Validation Loss: 0.69315404918628
# Early stopping triggered.
# Training time for this set of hyperparameters: 68.06 seconds
# Training model with hidden_dim=256, n_layers=2, bidirectional=False, dropout=0.2, lr=0.001
# Epoch 1/10
# Average training loss: 0.6933063940048217
# Running Validation...
# Validation Accuracy: 0.4978035143769968
# Validation Loss: 0.6936255965750819
# Epoch 2/10
# Average training loss: 0.6932630071004232
# Running Validation...
# Validation Accuracy: 0.4978035143769968
# Validation Loss: 0.6931442944005656
# Epoch 3/10
# Average training loss: 0.6932598122278849
# Running Validation...
# Validation Accuracy: 0.4978035143769968
# Validation Loss: 0.6932264821597943
# Epoch 4/10
# Average training loss: 0.6932324315388997
# Running Validation...
# Validation Accuracy: 0.5030950479233227
# Validation Loss: 0.6931295648169594
# Epoch 5/10
# Average training loss: 0.6932644497235616
# Running Validation...
# Validation Accuracy: 0.4978035143769968
# Validation Loss: 0.6931614781530521
# Epoch 6/10
# Average training loss: 0.6932214241981506
# Running Validation...
# Validation Accuracy: 0.4978035143769968
# Validation Loss: 0.6932118255109452
# Early stopping triggered.
# Training time for this set of hyperparameters: 50.84 seconds
# Training model with hidden_dim=256, n_layers=2, bidirectional=False, dropout=0.2, lr=0.0001
# Epoch 1/10
# Average training loss: 0.6931779246330261
# Running Validation...
# Validation Accuracy: 0.4978035143769968
# Validation Loss: 0.6932246282268256
# Epoch 2/10
# Average training loss: 0.6931630769093832
# Running Validation...
# Validation Accuracy: 0.5034944089456869
# Validation Loss: 0.6931287011209006
# Epoch 3/10
# Average training loss: 0.6931445478757222
# Running Validation...
# Validation Accuracy: 0.5014476837060703
# Validation Loss: 0.6931283278777577
# Epoch 4/10
# Average training loss: 0.693202867158254
# Running Validation...
# Validation Accuracy: 0.5043430511182109
# Validation Loss: 0.693131913773168
# Epoch 5/10
# Average training loss: 0.6931679368654887
# Running Validation...
# Validation Accuracy: 0.5082867412140575
# Validation Loss: 0.6931336671590044
# Early stopping triggered.
# Training time for this set of hyperparameters: 40.18 seconds
# Training model with hidden_dim=256, n_layers=2, bidirectional=False, dropout=0.3, lr=0.001
# Epoch 1/10
# Average training loss: 0.6934018763860067
# Running Validation...
# Validation Accuracy: 0.4978035143769968
# Validation Loss: 0.6931773883085282
# Epoch 2/10
# Average training loss: 0.69331428454717
# Running Validation...
# Validation Accuracy: 0.4978035143769968
# Validation Loss: 0.6932292451112034
# Epoch 3/10
# Average training loss: 0.6933069416364034
# Running Validation...
# Validation Accuracy: 0.4978035143769968
# Validation Loss: 0.6932110291319533
# Early stopping triggered.
# Training time for this set of hyperparameters: 23.21 seconds
# Training model with hidden_dim=256, n_layers=2, bidirectional=False, dropout=0.3, lr=0.0001
# Epoch 1/10
# Average training loss: 0.6932539057095846
# Running Validation...
# Validation Accuracy: 0.5029452875399361
# Validation Loss: 0.6931468071267247
# Epoch 2/10
# Average training loss: 0.69317895043691
# Running Validation...
# Validation Accuracy: 0.4978035143769968
# Validation Loss: 0.6932053984925389
# Epoch 3/10
# Average training loss: 0.6931941960652669
# Running Validation...
# Validation Accuracy: 0.5072384185303515
# Validation Loss: 0.6931418723191697
# Epoch 4/10
# Average training loss: 0.6932039484977722
# Running Validation...
# Validation Accuracy: 0.505491214057508
# Validation Loss: 0.6931357182824193
# Epoch 5/10
# Average training loss: 0.6931925354957581
# Running Validation...
# Validation Accuracy: 0.4978035143769968
# Validation Loss: 0.6932895133099236
# Epoch 6/10
# Average training loss: 0.6931622526804606
# Running Validation...
# Validation Accuracy: 0.5007488019169329
# Validation Loss: 0.6931229120435806
# Epoch 7/10
# Average training loss: 0.6931712076505026
# Running Validation...
# Validation Accuracy: 0.500848642172524
# Validation Loss: 0.6931222449666776
# Epoch 8/10
# Average training loss: 0.6931964023590088
# Running Validation...
# Validation Accuracy: 0.4978035143769968
# Validation Loss: 0.6931921920646875
# Epoch 9/10
# Average training loss: 0.6931832357088725
# Running Validation...
# Validation Accuracy: 0.49940095846645366
# Validation Loss: 0.6931553567750767
# Early stopping triggered.
# Training time for this set of hyperparameters: 72.06 seconds
# Best Model Parameters: {'hidden_dim': 256, 'n_layers': 2, 'bidirectional': False, 'dropout': 0.2, 'lr': 0.0001}
# Best Validation Accuracy: 0.5083
# Best Training Time: 40.18 seconds
# Test complete! Total prediction time: 0.41 seconds
#               precision    recall  f1-score   support
#
#            0     0.5167    0.2032    0.2917      9902
#            1     0.5102    0.8136    0.6271     10099
#
#     accuracy                         0.5114     20001
#    macro avg     0.5134    0.5084    0.4594     20001
# weighted avg     0.5134    0.5114    0.4610     20001
